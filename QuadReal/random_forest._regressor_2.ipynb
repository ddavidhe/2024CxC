# %%
import numpy as np 
import pandas as pd 

from sklearn.model_selection import train_test_split
from sklearn.model_selection import TimeSeriesSplit #for data preprocessing and crass validating 
from sklearn.model_selection import cross_validate
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.impute import SimpleImputer

from sklearn.linear_model import LogisticRegression #logistic Regression
from sklearn.ensemble import RandomForestRegressor #Random Forest 

from statistics import mean
from hyperopt import Trials, hp, fmin, tpe, STATUS_OK, space_eval #for hyperparameter tuning and minimizing

from cyclic_boosting.pipelines import pipeline_CBClassifier
from sklearn.ensemble import HistGradientBoostingRegressor

from datetime import date
from datetime import datetime

# %%
samples = pd.read_csv('unmerged_buildings.csv')
samples['date'] = pd.to_datetime(samples['date'])

reading_types = pd.read_csv('reading_types.csv')

samples.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 957826 entries, 0 to 957825
# Data columns (total 13 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Unnamed: 0     957826 non-null  int64
#  1   date           957826 non-null  datetime64[ns]
#  2   value_type_id  957826 non-null  int64
#  3   value          957826 non-null  float64
#  4   building_id    957826 non-null  int64
#  5   work_hours     957826 non-null  bool
#  6   day type       957826 non-null  int64
#  7   Fall           957826 non-null  bool
#  8   Spring         957826 non-null  bool
#  9   Summer         957826 non-null  bool
#  10  Winter         957826 non-null  bool
#  11  trimester_day  957826 non-null  int64
#  12  working_hour   957826 non-null  int64
# dtypes: bool(5), datetime64[ns](1), float64(1), int64(6)
# memory usage: 63.0 MB

# %%
for k, df in samples.groupby(by = ['building_id', 'value_type_id']):
    df = df.drop(columns=['value_type_id', 'Unnamed: 0'], axis = 1)
    df = df.sort_values(by='date') 

    df['prev_reading'] = df['value'].shift(1)
    df['after_reading'] = df['value'].shift(-1)

    df = df.ffill() 
    df = df.bfill()

    df = df.drop(columns = ['date'], axis = 1)

    df.info()
    x_train, x_test, y_train, y_test = train_test_split(df.drop(['value'], axis = 1), df['value'])
    tst_cv = TimeSeriesSplit(n_splits=5, gap = 48)

    space = {
    'n_estimators': hp.choice('n_estimators', range(50, 100)),
    'max_depth': hp.choice('max_depth', [1, 5, 10, 20, 50, 75, 100, 150, 200]),
    'min_samples_split': hp.choice('min_samples_split', [2, 3, 4, 5, 10, 20]),
    'min_samples_leaf': hp.choice('min_samples_leaf', [1, 2, 3, 4, 5]),
    'bootstrap': hp.choice('bootstrap', [True, False]),
    'criterion': hp.choice('criterion', ['squared_error', 'absolute_error', 'friedman_mse']),
    'max_features': hp.choice('max_features', ['sqrt', None, 'log2'])
    }

    # kfold = KFold(n_splits = 5, shuffle = True, random_state = 0)

    def objective(params):
        clf = RandomForestRegressor(**params)
        print(params)
        tst_cv = TimeSeriesSplit(n_splits=5, gap = 48)
        scores = cross_val_score(clf, x_train, y_train, cv = tst_cv, scoring = 'r2', n_jobs = -1)
        best_score = mean(scores) 
        loss = -best_score
        return {'loss': loss, 'params': params, 'status': STATUS_OK}

    num_trials = Trials()
    best = fmin(fn = objective, space = space, algo = tpe.suggest, max_evals = 40, trials = num_trials)

    randomForest = RandomForestRegressor(n_estimators = space_eval(space, best)['n_estimators'], max_depth = space_eval(space, best)['max_depth'],
                                        min_samples_split = space_eval(space, best)['min_samples_split'], min_samples_leaf = space_eval(space, best)['min_samples_leaf'],
                                        bootstrap = space_eval(space, best)['bootstrap'], criterion = space_eval(space, best)['criterion'], 
                                        max_features = space_eval(space, best)['max_features'])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6203 entries, 66071 to 45057
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   value          6203 non-null   float64
#  1   building_id    6203 non-null   int64
#  2   work_hours     6203 non-null   bool
#  3   day type       6203 non-null   int64
#  4   Fall           6203 non-null   bool
#  5   Spring         6203 non-null   bool
#  6   Summer         6203 non-null   bool
#  7   Winter         6203 non-null   bool
#  8   trimester_day  6203 non-null   int64
#  9   working_hour   6203 non-null   int64
#  10  prev_reading   6203 non-null   float64
#  11  after_reading  6203 non-null   float64
# dtypes: bool(5), float64(3), int64(4)
# memory usage: 418.0 KB
# {'bootstrap': False, 'criterion': 'friedman_mse', 'max_depth': 200, 'max_features': None, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 61}
# {'bootstrap': False, 'criterion': 'friedman_mse', 'max_depth': 10, 'max_features': None, 'min_samples_leaf': 5, 'min_samples_split': 20, 'n_estimators': 70}
# {'bootstrap': True, 'criterion': 'squared_error', 'max_depth': 75, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 88}
# {'bootstrap': True, 'criterion': 'friedman_mse', 'max_depth': 1, 'max_features': None, 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 59}
# {'bootstrap': False, 'criterion': 'friedman_mse', 'max_depth': 150, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 70}
# {'bootstrap': True, 'criterion': 'squared_error', 'max_depth': 75, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 75}
# {'bootstrap': True, 'criterion': 'squared_error', 'max_depth': 1, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 20, 'n_estimators': 99}
# {'bootstrap': True, 'criterion': 'absolute_error', 'max_depth': 50, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 99}
# {'bootstrap': False, 'criterion': 'absolute_error', 'max_depth': 150, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 84}
# {'bootstrap': False, 'criterion': 'absolute_error', 'max_depth': 50, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 20, 'n_estimators': 67}
# {'bootstrap': True, 'criterion': 'friedman_mse', 'max_depth': 1, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 55}
# {'bootstrap': False, 'criterion': 'absolute_error', 'max_depth': 50, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 73}
# {'bootstrap': False, 'criterion': 'friedman_mse', 'max_depth': 1, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 87}
# {'bootstrap': True, 'criterion': 'friedman_mse', 'max_depth': 200, 'max_features': None, 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 85}
# {'bootstrap': False, 'criterion': 'absolute_error', 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 82}
# {'bootstrap': False, 'criterion': 'friedman_mse', 'max_depth': 150, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 89}
# {'bootstrap': True, 'criterion': 'squared_error', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 62}
# {'bootstrap': False, 'criterion': 'friedman_mse', 'max_depth': 5, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 73}
# {'bootstrap': False, 'criterion': 'squared_error', 'max_depth': 5, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 71}
# {'bootstrap': False, 'criterion': 'absolute_error', 'max_depth': 100, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 68}
# {'bootstrap': True, 'criterion': 'squared_error', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 78}
# {'bootstrap': True, 'criterion': 'squared_error', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 62}
# {'bootstrap': True, 'criterion': 'absolute_error', 'max_depth': 50, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 54}
# {'bootstrap': True, 'criterion': 'absolute_error', 'max_depth': 50, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 57}
# {'bootstrap': True, 'criterion': 'squared_error', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 58}
# {'bootstrap': True, 'criterion': 'squared_error', 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 53}
# {'bootstrap': True, 'criterion': 'absolute_error', 'max_depth': 100, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 56}
# {'bootstrap': True, 'criterion': 'squared_error', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 92}
# {'bootstrap': True, 'criterion': 'absolute_error', 'max_depth': 200, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 93}
# {'bootstrap': True, 'criterion': 'absolute_error', 'max_depth': 50, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 91}
# {'bootstrap': True, 'criterion': 'squared_error', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'min_samples_split': 20, 'n_estimators': 97}
# {'bootstrap': True, 'criterion': 'squared_error', 'max_depth': 75, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'min_samples_split': 20, 'n_estimators': 80}
# {'bootstrap': True, 'criterion': 'absolute_error', 'max_depth': 100, 'max_features': None, 'min_samples_leaf': 3, 'min_samples_split': 20, 'n_estimators': 97}
# {'bootstrap': True, 'criterion': 'squared_error', 'max_depth': 50, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'min_samples_split': 20, 'n_estimators': 95}
# {'bootstrap': True, 'criterion': 'squared_error', 'max_depth': 5, 'max_features': None, 'min_samples_leaf': 3, 'min_samples_split': 20, 'n_estimators': 95}
# {'bootstrap': True, 'criterion': 'squared_error', 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'min_samples_split': 20, 'n_estimators': 76}
# {'bootstrap': True, 'criterion': 'squared_error', 'max_depth': 20, 'max_features': 'log2', 'min_samples_leaf': 3, 'min_samples_split': 20, 'n_estimators': 76}
# {'bootstrap': True, 'criterion': 'squared_error', 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'min_samples_split': 20, 'n_estimators': 50}
# {'bootstrap': True, 'criterion': 'squared_error', 'max_depth': 20, 'max_features': None, 'min_samples_leaf': 3, 'min_samples_split': 20, 'n_estimators': 77}
# {'bootstrap': True, 'criterion': 'squared_error', 'max_depth': 20, 'max_features': 'log2', 'min_samples_leaf': 3, 'min_samples_split': 20, 'n_estimators': 52}
# 100%|██████████| 40/40 [02:25<00:00,  3.63s/trial, best loss: -0.3558072017430938]
# <class 'pandas.core.frame.DataFrame'>
# Index: 6471 entries, 67121 to 22275
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   value          6471 non-null   float64
#  1   building_id    6471 non-null   int64
#  2   work_hours     6471 non-null   bool
#  3   day type       6471 non-null   int64
#  4   Fall           6471 non-null   bool
#  5   Spring         6471 non-null   bool
#  6   Summer         6471 non-null   bool
#  7   Winter         6471 non-null   bool
#  8   trimester_day  6471 non-null   int64
#  9   working_hour   6471 non-null   int64
#  10  prev_reading   6471 non-null   float64
#  11  after_reading  6471 non-null   float64
# dtypes: bool(5), float64(3), int64(4)
# memory usage: 436.0 KB
# {'bootstrap': True, 'criterion': 'absolute_error', 'max_depth': 50, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 72}
# {'bootstrap': True, 'criterion': 'friedman_mse', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 3, 'n_estimators': 76}
# {'bootstrap': True, 'criterion': 'absolute_error', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 57}
# {'bootstrap': True, 'criterion': 'friedman_mse', 'max_depth': 50, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 90}
# {'bootstrap': False, 'criterion': 'squared_error', 'max_depth': 200, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 10, 'n_estimators': 54}
# {'bootstrap': True, 'criterion': 'absolute_error', 'max_depth': 1, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 94}
# {'bootstrap': True, 'criterion': 'squared_error', 'max_depth': 150, 'max_features': None, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 62}
# {'bootstrap': True, 'criterion': 'friedman_mse', 'max_depth': 5, 'max_features': None, 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 79}
# {'bootstrap': True, 'criterion': 'absolute_error', 'max_depth': 10, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 20, 'n_estimators': 95}
# {'bootstrap': False, 'criterion': 'absolute_error', 'max_depth': 1, 'max_features': None, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 62}
# {'bootstrap': False, 'criterion': 'absolute_error', 'max_depth': 1, 'max_features': None, 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 71}
# {'bootstrap': True, 'criterion': 'squared_error', 'max_depth': 5, 'max_features': 'log2', 'min_samples_leaf': 3, 'min_samples_split': 3, 'n_estimators': 88}
# {'bootstrap': True, 'criterion': 'squared_error', 'max_depth': 75, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 52}
# {'bootstrap': True, 'criterion': 'absolute_error', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 52}
# {'bootstrap': True, 'criterion': 'friedman_mse', 'max_depth': 1, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 20, 'n_estimators': 82}
# {'bootstrap': False, 'criterion': 'absolute_error', 'max_depth': 50, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 88}
# {'bootstrap': True, 'criterion': 'absolute_error', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 61}
# {'bootstrap': True, 'criterion': 'absolute_error', 'max_depth': 150, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 90}
# {'bootstrap': False, 'criterion': 'squared_error', 'max_depth': 20, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 89}
# {'bootstrap': False, 'criterion': 'friedman_mse', 'max_depth': 50, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 95}
# {'bootstrap': False, 'criterion': 'friedman_mse', 'max_depth': 100, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 76}
# {'bootstrap': False, 'criterion': 'friedman_mse', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 65}
# {'bootstrap': False, 'criterion': 'friedman_mse', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 81}
# {'bootstrap': False, 'criterion': 'friedman_mse', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 65}
# {'bootstrap': False, 'criterion': 'friedman_mse', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 81}
# {'bootstrap': False, 'criterion': 'friedman_mse', 'max_depth': 75, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 85}
# {'bootstrap': False, 'criterion': 'friedman_mse', 'max_depth': 200, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 83}
# {'bootstrap': False, 'criterion': 'friedman_mse', 'max_depth': 100, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 96}
# {'bootstrap': False, 'criterion': 'friedman_mse', 'max_depth': 20, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 97}
# {'bootstrap': False, 'criterion': 'friedman_mse', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 70}
# {'bootstrap': False, 'criterion': 'friedman_mse', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 51}
# {'bootstrap': False, 'criterion': 'friedman_mse', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 51}
# {'bootstrap': False, 'criterion': 'friedman_mse', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 20, 'n_estimators': 68}
# {'bootstrap': False, 'criterion': 'friedman_mse', 'max_depth': 200, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 53}
# {'bootstrap': False, 'criterion': 'friedman_mse', 'max_depth': 75, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 77}
# {'bootstrap': False, 'criterion': 'squared_error', 'max_depth': 150, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 75}
# {'bootstrap': False, 'criterion': 'friedman_mse', 'max_depth': 100, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 99}
# {'bootstrap': False, 'criterion': 'friedman_mse', 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 98}
# {'bootstrap': False, 'criterion': 'squared_error', 'max_depth': 10, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 20, 'n_estimators': 51}
# {'bootstrap': False, 'criterion': 'friedman_mse', 'max_depth': 50, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 63}
# 100%|██████████| 40/40 [02:05<00:00,  3.13s/trial, best loss: -0.5943793993891564]
# <class 'pandas.core.frame.DataFrame'>
# Index: 5848 entries, 31518 to 9496
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   value          5848 non-null   float64
#  1   building_id    5848 non-null   int64
#  2   work_hours     5848 non-null   bool
#  3   day type       5848 non-null   int64
#  4   Fall           5848 non-null   bool
#  5   Spring         5848 non-null   bool
#  6   Summer         5848 non-null   bool
#  7   Winter         5848 non-null   bool
#  8   trimester_day  5848 non-null   int64
#  9   working_hour   5848 non-null   int64
#  10  prev_reading   5848 non-null   float64
#  11  after_reading  5848 non-null   float64
# dtypes: bool(5), float64(3), int64(4)
# memory usage: 394.1 KB
# {'bootstrap': False, 'criterion': 'friedman_mse', 'max_depth': 100, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'min_samples_split': 10, 'n_estimators': 94}
# {'bootstrap': True, 'criterion': 'absolute_error', 'max_depth': 100, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 76}
# {'bootstrap': True, 'criterion': 'absolute_error', 'max_depth': 20, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 10, 'n_estimators': 57}
# {'bootstrap': False, 'criterion': 'squared_error', 'max_depth': 100, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 96}
# {'bootstrap': True, 'criterion': 'absolute_error', 'max_depth': 5, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 70}
# {'bootstrap': False, 'criterion': 'squared_error', 'max_depth': 100, 'max_features': None, 'min_samples_leaf': 3, 'min_samples_split': 3, 'n_estimators': 78}
# {'bootstrap': False, 'criterion': 'friedman_mse', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'min_samples_split': 10, 'n_estimators': 80}
# {'bootstrap': False, 'criterion': 'friedman_mse', 'max_depth': 75, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 98}
# {'bootstrap': True, 'criterion': 'friedman_mse', 'max_depth': 100, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 93}
# {'bootstrap': False, 'criterion': 'friedman_mse', 'max_depth': 50, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 20, 'n_estimators': 64}
# {'bootstrap': False, 'criterion': 'absolute_error', 'max_depth': 200, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 84}
# {'bootstrap': False, 'criterion': 'friedman_mse', 'max_depth': 75, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 66}
# {'bootstrap': False, 'criterion': 'friedman_mse', 'max_depth': 50, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 10, 'n_estimators': 71}
# {'bootstrap': False, 'criterion': 'absolute_error', 'max_depth': 100, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 82}
# {'bootstrap': False, 'criterion': 'squared_error', 'max_depth': 10, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 92}
# {'bootstrap': False, 'criterion': 'squared_error', 'max_depth': 200, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 77}
# {'bootstrap': False, 'criterion': 'squared_error', 'max_depth': 1, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 94}
# {'bootstrap': True, 'criterion': 'absolute_error', 'max_depth': 200, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'min_samples_split': 10, 'n_estimators': 90}
# {'bootstrap': True, 'criterion': 'absolute_error', 'max_depth': 75, 'max_features': None, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 74}
# {'bootstrap': True, 'criterion': 'squared_error', 'max_depth': 50, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 57}
# {'bootstrap': False, 'criterion': 'friedman_mse', 'max_depth': 50, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 20, 'n_estimators': 64}
# {'bootstrap': False, 'criterion': 'friedman_mse', 'max_depth': 50, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 20, 'n_estimators': 71}
# {'bootstrap': False, 'criterion': 'friedman_mse', 'max_depth': 150, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 20, 'n_estimators': 59}
# {'bootstrap': False, 'criterion': 'friedman_mse', 'max_depth': 50, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 20, 'n_estimators': 83}
# {'bootstrap': False, 'criterion': 'friedman_mse', 'max_depth': 50, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 20, 'n_estimators': 86}
# {'bootstrap': False, 'criterion': 'friedman_mse', 'max_depth': 50, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 20, 'n_estimators': 86}
# {'bootstrap': False, 'criterion': 'friedman_mse', 'max_depth': 5, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 20, 'n_estimators': 83}
# {'bootstrap': False, 'criterion': 'friedman_mse', 'max_depth': 150, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 20, 'n_estimators': 52}
# {'bootstrap': False, 'criterion': 'friedman_mse', 'max_depth': 1, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 20, 'n_estimators': 67}
# {'bootstrap': False, 'criterion': 'friedman_mse', 'max_depth': 20, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 72}
# {'bootstrap': False, 'criterion': 'friedman_mse', 'max_depth': 50, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 20, 'n_estimators': 63}
# {'bootstrap': True, 'criterion': 'friedman_mse', 'max_depth': 50, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 20, 'n_estimators': 99}
# {'bootstrap': True, 'criterion': 'friedman_mse', 'max_depth': 20, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 20, 'n_estimators': 91}
# {'bootstrap': True, 'criterion': 'friedman_mse', 'max_depth': 5, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 99}
# {'bootstrap': True, 'criterion': 'absolute_error', 'max_depth': 150, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 79}
# {'bootstrap': True, 'criterion': 'squared_error', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 68}
# {'bootstrap': True, 'criterion': 'friedman_mse', 'max_depth': 50, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 20, 'n_estimators': 60}
# {'bootstrap': True, 'criterion': 'friedman_mse', 'max_depth': 1, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 97}
# {'bootstrap': True, 'criterion': 'friedman_mse', 'max_depth': 20, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 81}
# {'bootstrap': True, 'criterion': 'absolute_error', 'max_depth': 50, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 73}
# 100%|██████████| 40/40 [02:25<00:00,  3.63s/trial, best loss: -0.4911680904024863]
# <class 'pandas.core.frame.DataFrame'>
# Index: 6387 entries, 60735 to 52102
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   value          6387 non-null   float64
#  1   building_id    6387 non-null   int64
#  2   work_hours     6387 non-null   bool
#  3   day type       6387 non-null   int64
#  4   Fall           6387 non-null   bool
#  5   Spring         6387 non-null   bool
#  6   Summer         6387 non-null   bool
#  7   Winter         6387 non-null   bool
#  8   trimester_day  6387 non-null   int64
#  9   working_hour   6387 non-null   int64
#  10  prev_reading   6387 non-null   float64
#  11  after_reading  6387 non-null   float64
# dtypes: bool(5), float64(3), int64(4)
# memory usage: 430.4 KB
# {'bootstrap': False, 'criterion': 'squared_error', 'max_depth': 200, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'min_samples_split': 4, 'n_estimators': 76}
# {'bootstrap': True, 'criterion': 'friedman_mse', 'max_depth': 5, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 20, 'n_estimators': 61}
# {'bootstrap': True, 'criterion': 'squared_error', 'max_depth': 5, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 20, 'n_estimators': 51}
# {'bootstrap': True, 'criterion': 'absolute_error', 'max_depth': 50, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 77}
# {'bootstrap': True, 'criterion': 'absolute_error', 'max_depth': 150, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 88}
# {'bootstrap': False, 'criterion': 'friedman_mse', 'max_depth': 100, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 96}
# {'bootstrap': True, 'criterion': 'friedman_mse', 'max_depth': 200, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 54}
# {'bootstrap': True, 'criterion': 'absolute_error', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 75}
# {'bootstrap': False, 'criterion': 'squared_error', 'max_depth': 10, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 69}
# {'bootstrap': False, 'criterion': 'squared_error', 'max_depth': 75, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 20, 'n_estimators': 61}
# {'bootstrap': True, 'criterion': 'friedman_mse', 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 95}
# {'bootstrap': True, 'criterion': 'absolute_error', 'max_depth': 5, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 61}
# {'bootstrap': False, 'criterion': 'friedman_mse', 'max_depth': 50, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 90}
# {'bootstrap': True, 'criterion': 'squared_error', 'max_depth': 1, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 78}
# {'bootstrap': True, 'criterion': 'absolute_error', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 61}
# {'bootstrap': False, 'criterion': 'friedman_mse', 'max_depth': 150, 'max_features': 'log2', 'min_samples_leaf': 3, 'min_samples_split': 20, 'n_estimators': 55}
# {'bootstrap': True, 'criterion': 'squared_error', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 87}
# {'bootstrap': False, 'criterion': 'squared_error', 'max_depth': 150, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 87}
# {'bootstrap': True, 'criterion': 'absolute_error', 'max_depth': 1, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 20, 'n_estimators': 70}
# {'bootstrap': True, 'criterion': 'squared_error', 'max_depth': 150, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 20, 'n_estimators': 89}
# {'bootstrap': False, 'criterion': 'squared_error', 'max_depth': 200, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'min_samples_split': 3, 'n_estimators': 76}
# {'bootstrap': False, 'criterion': 'absolute_error', 'max_depth': 1, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'min_samples_split': 4, 'n_estimators': 70}
# {'bootstrap': False, 'criterion': 'squared_error', 'max_depth': 200, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 56}
# {'bootstrap': False, 'criterion': 'squared_error', 'max_depth': 200, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'min_samples_split': 3, 'n_estimators': 76}
# {'bootstrap': False, 'criterion': 'absolute_error', 'max_depth': 1, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'min_samples_split': 4, 'n_estimators': 82}
# {'bootstrap': False, 'criterion': 'squared_error', 'max_depth': 200, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 56}
# {'bootstrap': False, 'criterion': 'squared_error', 'max_depth': 200, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'min_samples_split': 3, 'n_estimators': 76}
# {'bootstrap': False, 'criterion': 'absolute_error', 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'min_samples_split': 4, 'n_estimators': 82}
# {'bootstrap': False, 'criterion': 'squared_error', 'max_depth': 200, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 60}
# {'bootstrap': False, 'criterion': 'squared_error', 'max_depth': 75, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'min_samples_split': 3, 'n_estimators': 86}
# {'bootstrap': False, 'criterion': 'absolute_error', 'max_depth': 20, 'max_features': None, 'min_samples_leaf': 3, 'min_samples_split': 4, 'n_estimators': 66}
# {'bootstrap': False, 'criterion': 'squared_error', 'max_depth': 100, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 60}
# {'bootstrap': False, 'criterion': 'squared_error', 'max_depth': 75, 'max_features': None, 'min_samples_leaf': 3, 'min_samples_split': 3, 'n_estimators': 86}
# {'bootstrap': False, 'criterion': 'absolute_error', 'max_depth': 20, 'max_features': None, 'min_samples_leaf': 3, 'min_samples_split': 10, 'n_estimators': 71}
# {'bootstrap': False, 'criterion': 'squared_error', 'max_depth': 100, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 64}
# {'bootstrap': True, 'criterion': 'friedman_mse', 'max_depth': 150, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 20, 'n_estimators': 68}
# {'bootstrap': False, 'criterion': 'squared_error', 'max_depth': 200, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'min_samples_split': 3, 'n_estimators': 62}
# {'bootstrap': False, 'criterion': 'squared_error', 'max_depth': 50, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'min_samples_split': 3, 'n_estimators': 58}
# {'bootstrap': False, 'criterion': 'absolute_error', 'max_depth': 1, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 98}
# {'bootstrap': False, 'criterion': 'absolute_error', 'max_depth': 1, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 63}
# 100%|██████████| 40/40 [00:10<00:00,  3.65trial/s, best loss: -1.0]
# <class 'pandas.core.frame.DataFrame'>
# Index: 6462 entries, 66279 to 25028
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   value          6462 non-null   float64
#  1   building_id    6462 non-null   int64
#  2   work_hours     6462 non-null   bool
#  3   day type       6462 non-null   int64
#  4   Fall           6462 non-null   bool
#  5   Spring         6462 non-null   bool
#  6   Summer         6462 non-null   bool
#  7   Winter         6462 non-null   bool
#  8   trimester_day  6462 non-null   int64
#  9   working_hour   6462 non-null   int64
#  10  prev_reading   6462 non-null   float64
#  11  after_reading  6462 non-null   float64
# dtypes: bool(5), float64(3), int64(4)
# memory usage: 435.4 KB
# {'bootstrap': True, 'criterion': 'absolute_error', 'max_depth': 100, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 87}
# {'bootstrap': True, 'criterion': 'squared_error', 'max_depth': 200, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 10, 'n_estimators': 89}
# {'bootstrap': True, 'criterion': 'squared_error', 'max_depth': 100, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 78}
# {'bootstrap': True, 'criterion': 'friedman_mse', 'max_depth': 75, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 3, 'n_estimators': 83}
# {'bootstrap': True, 'criterion': 'squared_error', 'max_depth': 150, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 95}
# {'bootstrap': True, 'criterion': 'absolute_error', 'max_depth': 75, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 20, 'n_estimators': 68}
# {'bootstrap': True, 'criterion': 'absolute_error', 'max_depth': 100, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 3, 'n_estimators': 52}
# {'bootstrap': True, 'criterion': 'absolute_error', 'max_depth': 10, 'max_features': None, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 78}
# {'bootstrap': False, 'criterion': 'friedman_mse', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 90}
# {'bootstrap': False, 'criterion': 'squared_error', 'max_depth': 50, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 90}
# {'bootstrap': True, 'criterion': 'friedman_mse', 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 78}
# {'bootstrap': False, 'criterion': 'squared_error', 'max_depth': 5, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 20, 'n_estimators': 98}
# {'bootstrap': False, 'criterion': 'squared_error', 'max_depth': 50, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 72}
# {'bootstrap': True, 'criterion': 'squared_error', 'max_depth': 200, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'min_samples_split': 10, 'n_estimators': 93}
# {'bootstrap': False, 'criterion': 'squared_error', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 20, 'n_estimators': 88}
# {'bootstrap': False, 'criterion': 'absolute_error', 'max_depth': 50, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 20, 'n_estimators': 93}
# {'bootstrap': True, 'criterion': 'absolute_error', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 20, 'n_estimators': 63}
# {'bootstrap': True, 'criterion': 'absolute_error', 'max_depth': 1, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 50}
# {'bootstrap': False, 'criterion': 'absolute_error', 'max_depth': 150, 'max_features': 'log2', 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 67}
# {'bootstrap': False, 'criterion': 'absolute_error', 'max_depth': 100, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 71}
# {'bootstrap': True, 'criterion': 'absolute_error', 'max_depth': 1, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 87}
# {'bootstrap': False, 'criterion': 'absolute_error', 'max_depth': 150, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 67}
# {'bootstrap': False, 'criterion': 'absolute_error', 'max_depth': 100, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'min_samples_split': 4, 'n_estimators': 71}
# {'bootstrap': True, 'criterion': 'absolute_error', 'max_depth': 1, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 58}
# {'bootstrap': False, 'criterion': 'friedman_mse', 'max_depth': 150, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 57}
# {'bootstrap': False, 'criterion': 'absolute_error', 'max_depth': 100, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 86}
# {'bootstrap': True, 'criterion': 'absolute_error', 'max_depth': 1, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 96}
#  65%|██████▌   | 26/40 [00:12<00:06,  2.10trial/s, best loss: -1.0]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 39
#      36     return {'loss': loss, 'params': params, 'status': STATUS_OK}
#      38 num_trials = Trials()
# ---> 39 best = fmin(fn = objective, space = space, algo = tpe.suggest, max_evals = 40, trials = num_trials)
#      41 randomForest = RandomForestRegressor(n_estimators = space_eval(space, best)['n_estimators'], max_depth = space_eval(space, best)['max_depth'],
#      42                                     min_samples_split = space_eval(space, best)['min_samples_split'], min_samples_leaf = space_eval(space, best)['min_samples_leaf'],
#      43                                     bootstrap = space_eval(space, best)['bootstrap'], criterion = space_eval(space, best)['criterion'],
#      44                                     max_features = space_eval(space, best)['max_features'])
#
# File c:\Users\Thomas\AppData\Local\Programs\Python\Python311\Lib\site-packages\hyperopt\fmin.py:540, in fmin(fn, space, algo, max_evals, timeout, loss_threshold, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar, early_stop_fn, trials_save_file)
#     537     fn = __objective_fmin_wrapper(fn)
#     539 if allow_trials_fmin and hasattr(trials, "fmin"):
# --> 540     return trials.fmin(
#     541         fn,
#     542         space,
#     543         algo=algo,
#     544         max_evals=max_evals,
#     545         timeout=timeout,
#     546         loss_threshold=loss_threshold,
#     547         max_queue_len=max_queue_len,
#     548         rstate=rstate,
#     549         pass_expr_memo_ctrl=pass_expr_memo_ctrl,
#     550         verbose=verbose,
#     551         catch_eval_exceptions=catch_eval_exceptions,
#     552         return_argmin=return_argmin,
#     553         show_progressbar=show_progressbar,
#     554         early_stop_fn=early_stop_fn,
#     555         trials_save_file=trials_save_file,
#     556     )
#     558 if trials is None:
#     559     if os.path.exists(trials_save_file):
#
# File c:\Users\Thomas\AppData\Local\Programs\Python\Python311\Lib\site-packages\hyperopt\base.py:671, in Trials.fmin(self, fn, space, algo, max_evals, timeout, loss_threshold, max_queue_len, rstate, verbose, pass_expr_memo_ctrl, catch_eval_exceptions, return_argmin, show_progressbar, early_stop_fn, trials_save_file)
#     666 # -- Stop-gap implementation!
#     667 #    fmin should have been a Trials method in the first place
#     668 #    but for now it's still sitting in another file.
#     669 from .fmin import fmin
# --> 671 return fmin(
#     672     fn,
#     673     space,
#     674     algo=algo,
#     675     max_evals=max_evals,
#     676     timeout=timeout,
#     677     loss_threshold=loss_threshold,
#     678     trials=self,
#     679     rstate=rstate,
#     680     verbose=verbose,
#     681     max_queue_len=max_queue_len,
#     682     allow_trials_fmin=False,  # -- prevent recursion
#     683     pass_expr_memo_ctrl=pass_expr_memo_ctrl,
#     684     catch_eval_exceptions=catch_eval_exceptions,
#     685     return_argmin=return_argmin,
#     686     show_progressbar=show_progressbar,
#     687     early_stop_fn=early_stop_fn,
#     688     trials_save_file=trials_save_file,
#     689 )
#
# File c:\Users\Thomas\AppData\Local\Programs\Python\Python311\Lib\site-packages\hyperopt\fmin.py:586, in fmin(fn, space, algo, max_evals, timeout, loss_threshold, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar, early_stop_fn, trials_save_file)
#     583 rval.catch_eval_exceptions = catch_eval_exceptions
#     585 # next line is where the fmin is actually executed
# --> 586 rval.exhaust()
#     588 if return_argmin:
#     589     if len(trials.trials) == 0:
#
# File c:\Users\Thomas\AppData\Local\Programs\Python\Python311\Lib\site-packages\hyperopt\fmin.py:364, in FMinIter.exhaust(self)
#     362 def exhaust(self):
#     363     n_done = len(self.trials)
# --> 364     self.run(self.max_evals - n_done, block_until_done=self.asynchronous)
#     365     self.trials.refresh()
#     366     return self
#
# File c:\Users\Thomas\AppData\Local\Programs\Python\Python311\Lib\site-packages\hyperopt\fmin.py:300, in FMinIter.run(self, N, block_until_done)
#     297     time.sleep(self.poll_interval_secs)
#     298 else:
#     299     # -- loop over trials and do the jobs directly
# --> 300     self.serial_evaluate()
#     302 self.trials.refresh()
#     303 if self.trials_save_file != "":
#
# File c:\Users\Thomas\AppData\Local\Programs\Python\Python311\Lib\site-packages\hyperopt\fmin.py:178, in FMinIter.serial_evaluate(self, N)
#     176 ctrl = base.Ctrl(self.trials, current_trial=trial)
#     177 try:
# --> 178     result = self.domain.evaluate(spec, ctrl)
#     179 except Exception as e:
#     180     logger.error("job exception: %s" % str(e))
#
# File c:\Users\Thomas\AppData\Local\Programs\Python\Python311\Lib\site-packages\hyperopt\base.py:892, in Domain.evaluate(self, config, ctrl, attach_attachments)
#     883 else:
#     884     # -- the "work" of evaluating `config` can be written
#     885     #    either into the pyll part (self.expr)
#     886     #    or the normal Python part (self.fn)
#     887     pyll_rval = pyll.rec_eval(
#     888         self.expr,
#     889         memo=memo,
#     890         print_node_on_error=self.rec_eval_print_node_on_error,
#     891     )
# --> 892     rval = self.fn(pyll_rval)
#     894 if isinstance(rval, (float, int, np.number)):
#     895     dict_rval = {"loss": float(rval), "status": STATUS_OK}
#
# Cell In[10], line 33, in objective(params)
#      31 print(params)
#      32 tst_cv = TimeSeriesSplit(n_splits=5, gap = 48)
# ---> 33 scores = cross_val_score(clf, x_train, y_train, cv = tst_cv, scoring = 'r2', n_jobs = -1)
#      34 best_score = mean(scores)
#      35 loss = -best_score
#
# File c:\Users\Thomas\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py:562, in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, error_score)
#     559 # To ensure multimetric format is not supported
#     560 scorer = check_scoring(estimator, scoring=scoring)
# --> 562 cv_results = cross_validate(
#     563     estimator=estimator,
#     564     X=X,
#     565     y=y,
#     566     groups=groups,
#     567     scoring={"score": scorer},
#     568     cv=cv,
#     569     n_jobs=n_jobs,
#     570     verbose=verbose,
#     571     fit_params=fit_params,
#     572     pre_dispatch=pre_dispatch,
#     573     error_score=error_score,
#     574 )
#     575 return cv_results["test_score"]
#
# File c:\Users\Thomas\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_param_validation.py:214, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     208 try:
#     209     with config_context(
#     210         skip_parameter_validation=(
#     211             prefer_skip_nested_validation or global_skip_validation
#     212         )
#     213     ):
# --> 214         return func(*args, **kwargs)
#     215 except InvalidParameterError as e:
#     216     # When the function is just a wrapper around an estimator, we allow
#     217     # the function to delegate validation to the estimator, but we replace
#     218     # the name of the estimator by the name of the function in the error
#     219     # message to avoid confusion.
#     220     msg = re.sub(
#     221         r"parameter of \w+ must be",
#     222         f"parameter of {func.__qualname__} must be",
#     223         str(e),
#     224     )
#
# File c:\Users\Thomas\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py:309, in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score, return_estimator, return_indices, error_score)
#     306 # We clone the estimator to make sure that all the folds are
#     307 # independent, and that it is pickle-able.
#     308 parallel = Parallel(n_jobs=n_jobs, verbose=verbose, pre_dispatch=pre_dispatch)
# --> 309 results = parallel(
#     310     delayed(_fit_and_score)(
#     311         clone(estimator),
#     312         X,
#     313         y,
#     314         scorers,
#     315         train,
#     316         test,
#     317         verbose,
#     318         None,
#     319         fit_params,
#     320         return_train_score=return_train_score,
#     321         return_times=True,
#     322         return_estimator=return_estimator,
#     323         error_score=error_score,
#     324     )
#     325     for train, test in indices
#     326 )
#     328 _warn_or_raise_about_fit_failures(results, error_score)
#     330 # For callable scoring, the return type is only know after calling. If the
#     331 # return type is a dictionary, the error scores can now be inserted with
#     332 # the correct key.
#
# File c:\Users\Thomas\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\parallel.py:65, in Parallel.__call__(self, iterable)
#      60 config = get_config()
#      61 iterable_with_config = (
#      62     (_with_config(delayed_func, config), args, kwargs)
#      63     for delayed_func, args, kwargs in iterable
#      64 )
# ---> 65 return super().__call__(iterable_with_config)
#
# File c:\Users\Thomas\AppData\Local\Programs\Python\Python311\Lib\site-packages\joblib\parallel.py:1952, in Parallel.__call__(self, iterable)
#    1946 # The first item from the output is blank, but it makes the interpreter
#    1947 # progress until it enters the Try/Except block of the generator and
#    1948 # reach the first `yield` statement. This starts the aynchronous
#    1949 # dispatch of the tasks to the workers.
#    1950 next(output)
# -> 1952 return output if self.return_generator else list(output)
#
# File c:\Users\Thomas\AppData\Local\Programs\Python\Python311\Lib\site-packages\joblib\parallel.py:1595, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1592     yield
#    1594     with self._backend.retrieval_context():
# -> 1595         yield from self._retrieve()
#    1597 except GeneratorExit:
#    1598     # The generator has been garbage collected before being fully
#    1599     # consumed. This aborts the remaining tasks if possible and warn
#    1600     # the user if necessary.
#    1601     self._exception = True
#
# File c:\Users\Thomas\AppData\Local\Programs\Python\Python311\Lib\site-packages\joblib\parallel.py:1707, in Parallel._retrieve(self)
#    1702 # If the next job is not ready for retrieval yet, we just wait for
#    1703 # async callbacks to progress.
#    1704 if ((len(self._jobs) == 0) or
#    1705     (self._jobs[0].get_status(
#    1706         timeout=self.timeout) == TASK_PENDING)):
# -> 1707     time.sleep(0.01)
#    1708     continue
#    1710 # We need to be careful: the job list can be filling up as
#    1711 # we empty it and Python list are not thread-safe by
#    1712 # default hence the use of the lock
#
# KeyboardInterrupt:
