# %%
import warnings
warnings.filterwarnings("ignore")
import numpy as np 
import pandas as pd 
import os 
import  random 
import sys 
import matplotlib.pyplot as plt 
import ee #to use google's earth engine 
import math
from matplotlib import pyplot as plt
import seaborn as sns
from collections import Counter

# %%
df = pd.read_csv('preprocessed.csv')
df['date'] = pd.to_datetime(df['date'])

# %% [markdown]
# ### 2023 - 2024 all data values

# %%
start_date = '2023-8-01'
end_date = '2023-8-30'
filtered_df = df[(df['date'] >= start_date) & (df['date'] <= end_date) & (df['device_id'] == 1) & (df['value_type_id'] == 1)]

filtered_df.info()

# g = sns.FacetGrid(df, col="value_type_id")
sns.lineplot(x = "date", y = "value", data = filtered_df, ci=None)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 60 entries, 49 to 5019
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     60 non-null     int64
#  1   device_id      60 non-null     int64
#  2   date           60 non-null     datetime64[ns]
#  3   value_type_id  60 non-null     int64
#  4   value          60 non-null     float64
#  5   work_hours     60 non-null     bool
#  6   season         60 non-null     object
#  7   day type       60 non-null     int64
#  8   building_id    60 non-null     int64
# dtypes: bool(1), datetime64[ns](1), float64(1), int64(5), object(1)
# memory usage: 4.3+ KB
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 8
#       5 filtered_df.info()
#       7 # g = sns.FacetGrid(df, col="value_type_id")
# ...
