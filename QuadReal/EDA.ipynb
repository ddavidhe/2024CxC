# %%
import warnings
warnings.filterwarnings("ignore")
import numpy as np 
import pandas as pd 
import os 
import  random 
import sys 
import matplotlib.pyplot as plt 
import ee #to use google's earth engine 
import math
from matplotlib import pyplot as plt
import seaborn as sns
from collections import Counter

# %%
df = pd.read_csv('preprocessed.csv')
df['date'] = pd.to_datetime(df['date'])
reading_types = pd.read_csv('reading_types.csv')
reading_types.info() 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 2 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   reading_type_id    12 non-null     int64
#  1   reading_type_name  12 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 324.0+ bytes
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 957826 entries, 0 to 957825
# Data columns (total 41 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Unnamed: 0     957826 non-null  int64
#  1   date           957826 non-null  datetime64[ns]
#  2   value_type_id  957826 non-null  int64
#  3   value          957826 non-null  float64
#  4   work_hours     957826 non-null  bool
#  5   day type       957826 non-null  int64
#  6   Fall           957826 non-null  bool
#  7   Spring         957826 non-null  bool
#  8   Summer         957826 non-null  bool
# ...

# %% [markdown]
# ### 2023 - 2024 all data values

# %%
start_date = '2023-01-01'
end_date = '2023-12-31'
filtered_df = df[(df['date'] >= start_date) & (df['date'] <= end_date) & (df['building_1'] == 1)]



# g = sns.FacetGrid(df, col="value_type_id")
for k, v in filtered_df.groupby('value_type_id'):
    fig, ax = plt.subplots() 
    fig = sns.lineplot(x = "date", y = "value", data = v).set_title(reading_types.at[k - 1, 'reading_type_name']) 
    x_dates = v['date'].dt.strftime('%m-%d').sort_values().unique()
    # ax.set_xticklabels(rotation = 45, ha = 'right')

# %% [markdown]
# ### WEEKLY DATA FOR AUGUST

# %%
start_date = '2023-08-01'
end_date = '2023-08-30'
filtered_df = df[(df['date'] >= start_date) & (df['date'] <= end_date) & (df['building_1'] == 1)]



# g = sns.FacetGrid(df, col="value_type_id")
for k, v in filtered_df.groupby('value_type_id'):
    fig, ax = plt.subplots() 
    fig = sns.lineplot(x = "date", y = "value", data = v).set_title(reading_types.at[k - 1, 'reading_type_name']) 
    x_dates = v['date'].dt.strftime('%Y-%m-%d').sort_values().unique()
    ax.set_xticklabels(labels = x_dates, rotation = 45, ha = 'right')

# %%
start_date = '2023-08-01'
end_date = '2023-08-30'
filtered_df = df[(df['date'] >= start_date) & (df['date'] <= end_date) & (df['building_2'] == 1)]



# g = sns.FacetGrid(df, col="value_type_id")
for k, v in filtered_df.groupby('value_type_id'):
    fig, ax = plt.subplots() 
    fig = sns.lineplot(x = "date", y = "value", data = v).set_title(reading_types.at[k - 1, 'reading_type_name']) 
    x_dates = v['date'].dt.strftime('%Y-%m-%d').sort_values().unique()
    ax.set_xticklabels(labels = x_dates, rotation = 45, ha = 'right')

# %% [markdown]
# ### Normality of distributions

# %%
main = pd.read_csv('preprocessed_lstm.csv')
for k, df in main.groupby('building_id'): 
    # for valType, df in df1.groupby('value_type_id'): 
    plt.figure(plt.figure(figsize = (14,5)))
    sns.distplot(df['11'])

# %% [markdown]
# ### Correlation Matrix

# %%
start_date = '2023-05-13 12'
end_date = '2023-05-13 16'
filtered_df = df[(df['date'] >= start_date) & (df['date'] <= end_date) & (df['building_1'] == 1)]



# g = sns.FacetGrid(df, col="value_type_id")
for k, v in filtered_df.groupby('value_type_id'):
    fig, ax = plt.subplots() 
    fig = sns.lineplot(x = "date", y = "value", data = v).set_title(reading_types.at[k - 1, 'reading_type_name']) 
    x_dates = v['date'].dt.strftime('%H:%m').sort_values().unique()
    ax.set_xticklabels(labels = x_dates, rotation = 45, ha = 'right')
