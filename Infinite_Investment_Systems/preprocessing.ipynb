# %%
import pandas as pd
import math

# %%
df = pd.read_csv("test.csv")
df.head()
df_filtered = df.drop(columns=['country_code'],axis=1)
df_filtered.head()
# Out:
# /var/folders/y2/7tlzzx7910n05m39_4jm33qh0000gn/T/ipykernel_24731/3329497883.py:1: DtypeWarning: Columns (62,64,87) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("test.csv")
#         id type_code is_registered currency_code is_active  class_id  \
# 0  1155742      CASH             f           CAD         t       3.0
# 1  1269359      TFSA             t           CAD         t       5.0
# 2   573181      CASH             f           CAD         t       3.0
# 3   967968      TFSA             t           CAD         t       5.0
# 4   595581      CASH             f           CAD         t       3.0
#
#   debit_code last_trade_date  contract_type inception_date  ...  \
# 0          T             NaN           17.0     2017-07-21  ...
# 1          C      2020-11-05           18.0     2020-03-09  ...
# 2          T             NaN           17.0     2023-01-10  ...
# 3          A      2020-03-03           17.0     2017-07-21  ...
# 4          T      2011-04-01           17.0     2009-02-18  ...
#
#   is_family_resp  is_hrdc_resp is_plan_grandfathered resp_specimen_plan  \
# 0            NaN           NaN                   NaN                NaN
# 1              f             f                     f                NaN
# 2            NaN           NaN                   NaN                NaN
# 3              f             f                     f                NaN
# 4            NaN           NaN                   NaN                NaN
#
#                      inserted_at                     updated_at is_olob  \
# 0  2023-05-30 14:20:18.531115+00  2023-08-08 18:53:01.439561+00       f
# 1  2023-05-30 14:20:18.531115+00  2023-08-10 21:47:25.370403+00       f
# 2  2023-05-30 14:20:18.531115+00  2023-08-08 18:53:01.439561+00       f
# 3  2023-05-30 14:20:18.531115+00  2023-08-10 21:47:25.370403+00       f
# 4  2023-05-30 14:20:18.531115+00  2023-08-08 20:37:22.511698+00       f
#
#   retail_last_maintenance_time  retail_last_maintenance_user  \
# 0                          NaN                           NaN
# 1          2022-10-20 00:00:00                       ROMANAA
# 2                          NaN                           NaN
# 3          2021-08-06 00:00:00                           T80
# 4                          NaN                           NaN
#
#   visible_in_reports
# 0                  t
# 1                  t
# 2                  t
# 3                  f
# 4                  t
#
# [5 rows x 104 columns]

# %%
pd.set_option('display.max_rows', 120)
df.nunique(dropna=False)
# Out:
# id                                    673339
# type_code                                 21
# is_registered                              2
# country_code                               2
# currency_code                              2
# is_active                                  2
# class_id                                  66
# debit_code                                25
# last_trade_date                         5028
# contract_type                             20
# inception_date                          5889
# net_of_fees                                1
# cashflows_custody_fee                      1
# fee_paid_separately                        1
# custody_fee_withdrawal                     1
# is_fee_exempt                              1
# branch                                    10
# include_client_consolidation               2
# use_client_address                         2
# credit_limit_type                          6
# retail_plan                               10
# is_spousal                                 3
# is_arp_locked                              3
# arp_pension_origin                        13
# language_code                              3
# dividend_confirm_code                      7
# sss_location                               6
# options_trading_type                       7
# sss_type                                   3
# sss_agent                               3816
# is_midwest_clearing_account                2
# rep_commission_rate                        2
# rep_commission_override                    3
# interest_dividend_conversion_type          3
# guarantee_gtor_type                        5
# use_hand_delivery                          2
# use_mail                                   2
# share_name_address_to_issuer               2
# shareholder_instructions_received          2
# rrsp_limit_reached                         1
# is_portfolio_account                       1
# has_no_min_commission                      1
# is_tms_eligible                            2
# is_agent_bbs_participant                   2
# is_parameters_account                      1
# is_spousal_transfer                        2
# spousal_age_flag                           1
# terminal_code                           1439
# has_multiple_name                          2
# deceased_fair_market_value              2126
# target_grantor_grantee_flag                4
# discretionary_trading_authorized           3
# iso_funds_code                             3
# esir_number                               11
# shareholder_language                       3
# dup_trip_quad_code                         2
# special_tag                               10
# conjunction                                5
# title                                     64
# function_code                             24
# tms_settlement_location                   15
# portfolio_cost_method                      2
# portfolio_name_address_option              2
# portfolio_report_option                    5
# portfolio_summary_option                   2
# receive_general_mailings                   2
# loan_limit_override                        4
# interactive_portfolio_code                 2
# non_plan_book_value_flag                   2
# has_discrete_auth                          2
# last_update_date                        4987
# is_non_objecting_beneficial_owner          2
# is_objecting_to_disclose_info              2
# mailing_consent                            3
# consent_to_pay_for_mail                    2
# consent_to_email_delivery                  2
# has_received_instruction                   2
# risk_tolerance                           848
# investment_objective                    1472
# is_broker_account                          1
# is_inventory_account                       2
# is_gl_account                              1
# is_control_account                         1
# is_extract_eligible                        2
# last_maintenance_time                   1735
# last_maintenance_user                    445
# is_pledged                                 3
# special_fee_code                          36
# non_calendar_year_end                      5
# plan_effective_date                     5521
# plan_end_date                           3584
# is_resp                                    3
# number_of_beneficiaries                   14
# rrif_original_date                      6717
# use_original_date_for_payment_calc         3
# is_family_resp                             3
# is_hrdc_resp                               3
# is_plan_grandfathered                      2
# resp_specimen_plan                         7
# inserted_at                              141
# updated_at                               214
# is_olob                                    2
# retail_last_maintenance_time            2903
# retail_last_maintenance_user             433
# visible_in_reports                         2
# label                                      2
# dtype: int64
