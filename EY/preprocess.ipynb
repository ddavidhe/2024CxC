# %%
import pandas as pd

# %%
#df = pd.read_excel('fp-historical-wildfire-data-2006-2021.xlsx')
#df.to_csv('converted-data.csv')
# only really need to run this once

# %% [markdown]
# Actually Preprocessing

# %%
df = pd.read_csv("converted-data.csv")
df
# Out:
#        Unnamed: 0  fire_year fire_number fire_name  current_size size_class  \
# 0               0       2021      HWF053       NaN          5.50          C
# 1               1       2021      RWF005       NaN          0.01          A
# 2               2       2021      LWF014       NaN          0.10          A
# 3               3       2021      MWF002       NaN          0.01          A
# 4               4       2021      EWF014       NaN          7.13          C
# ...           ...        ...         ...       ...           ...        ...
# 22909       22909       2006      CWF231       NaN          0.10          A
# 22910       22910       2006      CWF232       NaN          0.01          A
# 22911       22911       2006      CWF233       NaN          0.70          B
# 22912       22912       2006      CWF234       NaN          0.01          A
# 22913       22913       2006      MWF174       NaN          0.01          A
#
# ...

# %%
df = df.drop(df.columns[0], axis=1)
df.head()
# Out:
#    fire_year fire_number fire_name  current_size size_class  \
# 0       2021      HWF053       NaN          5.50          C
# 1       2021      RWF005       NaN          0.01          A
# 2       2021      LWF014       NaN          0.10          A
# 3       2021      MWF002       NaN          0.01          A
# 4       2021      EWF014       NaN          7.13          C
#
#    fire_location_latitude  fire_location_longitude         fire_origin  \
# 0               59.522139              -119.926971     Provincial Land
# 1               52.692262              -116.118960     Provincial Land
# 2               55.937050              -110.719950  Indian Reservation
# 3               56.425933              -111.160750  Indian Reservation
# 4               53.693450              -116.058633        Private Land
#
#   general_cause_desc industry_identifier_desc  ... distance_from_water_source  \
# 0          Lightning                      NaN  ...                        NaN
# ...

# %% [markdown]
# Notes:

# %% [markdown]
# fire_type is a binary metric (either Ground, or Surface)

# %%
df_test = df

df_test['size_class'] = df_test['fire_type'].replace({'C': 1, 'A': 0})
df_test.head()
# Out:
#    fire_year fire_number fire_name  current_size size_class  \
# 0       2021      HWF053       NaN          5.50          0
# 1       2021      RWF005       NaN          0.01          1
# 2       2021      LWF014       NaN          0.10          0
# 3       2021      MWF002       NaN          0.01          0
# 4       2021      EWF014       NaN          7.13          0
#
#    fire_location_latitude  fire_location_longitude         fire_origin  \
# 0               59.522139              -119.926971     Provincial Land
# 1               52.692262              -116.118960     Provincial Land
# 2               55.937050              -110.719950  Indian Reservation
# 3               56.425933              -111.160750  Indian Reservation
# 4               53.693450              -116.058633        Private Land
#
#   general_cause_desc industry_identifier_desc  ... distance_from_water_source  \
# 0          Lightning                      NaN  ...                        NaN
# ...
