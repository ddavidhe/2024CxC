# %%
import pandas as pd

# %%
df = pd.read_excel('fp-historical-wildfire-data-2006-2021.xlsx')
df.to_csv('converted-data.csv')

# %% [markdown]
# Actually Preprocessing

# %%
df = pd.read_csv("converted-data.csv")
df.head()
# Out:
#    Unnamed: 0  fire_year fire_number fire_name  current_size size_class  \
# 0           0       2021      HWF053       NaN          5.50          C
# 1           1       2021      RWF005       NaN          0.01          A
# 2           2       2021      LWF014       NaN          0.10          A
# 3           3       2021      MWF002       NaN          0.01          A
# 4           4       2021      EWF014       NaN          7.13          C
#
#    fire_location_latitude  fire_location_longitude         fire_origin  \
# 0               59.522139              -119.926971     Provincial Land
# 1               52.692262              -116.118960     Provincial Land
# 2               55.937050              -110.719950  Indian Reservation
# 3               56.425933              -111.160750  Indian Reservation
# 4               53.693450              -116.058633        Private Land
#
#   general_cause_desc  ... distance_from_water_source first_bucket_drop_date  \
# 0          Lightning  ...                        NaN                    NaN
# 1    Forest Industry  ...                        NaN                    NaN
# 2         Incendiary  ...                        NaN                    NaN
# 3           Resident  ...                        NaN                    NaN
# 4           Resident  ...                        NaN                    NaN
#
#             bh_fs_date bh_hectares           uc_fs_date uc_hectares  \
# 0  2021-06-28 22:26:00        0.01  2021-07-01 13:26:00       10.00
# 1  2021-03-30 14:30:00        0.01  2021-03-30 14:30:00        0.01
# 2  2021-04-16 16:57:00        0.10  2021-04-16 16:57:00        0.10
# 3  2021-04-17 15:20:00        0.01  2021-04-17 15:20:00        0.01
# 4  2021-04-01 19:10:00        7.13  2021-04-02 11:00:00        7.13
#
#             to_fs_date to_hectares           ex_fs_date ex_hectares
# 0                  NaN         NaN  2021-07-01 13:44:00        5.50
# 1  2021-03-30 14:35:00        0.01  2021-04-09 08:30:00        0.01
# 2                  NaN         NaN  2021-04-17 14:15:00        0.10
# 3                  NaN         NaN  2021-04-17 15:24:00        0.01
# 4  2021-04-02 15:52:00        7.13  2021-04-12 14:30:00        7.13
#
# [5 rows x 51 columns]
